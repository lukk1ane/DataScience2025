# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
temperatures = np.arange(1, 8)


plt.plot(days, temperatures, marker='o', color='orange', linestyle='--')
plt.xlabel("Day of the Week")
plt.ylabel("Temperature (°C)")
plt.title("Temperature Changes Over a Week")
plt.grid(True)

# %%
days = np.arange(1, 31)
product_a = np.random.randint(20, 50, size=30)
product_b = np.random.randint(15, 60, size=30)

plt.plot(days, product_a, label="Product 1", marker="o")
plt.plot(days, product_b, label="Product 2", marker="s")
plt.xlabel("Month")
plt.ylabel("Sold")
plt.title("comparison")
plt.legend()
plt.grid(True)

# %%
df = pd.DataFrame(
    {"X": np.random.rand(30), "Y": np.random.rand(30), "Z": np.random.rand(30)}
)
df
# Out:
#            X         Y         Z
# 0   0.741737  0.440286  0.462807
# 1   0.418080  0.782241  0.506289
# 2   0.006131  0.047421  0.873086
# 3   0.300458  0.929926  0.980534
# 4   0.213174  0.647505  0.274414
# 5   0.918719  0.052955  0.264238
# 6   0.219516  0.632916  0.478451
# 7   0.501543  0.423497  0.058779
# 8   0.697601  0.090643  0.424747
# 9   0.611984  0.545087  0.322025
# 10  0.624755  0.264659  0.045704
# 11  0.653370  0.147203  0.579801
# 12  0.988331  0.175450  0.714843
# 13  0.843717  0.485768  0.852907
# 14  0.056705  0.180841  0.648543
# 15  0.804330  0.292011  0.342499
# 16  0.703373  0.137180  0.726365
# 17  0.199919  0.292527  0.205551
# 18  0.823833  0.784774  0.507731
# 19  0.733807  0.952807  0.720954
# 20  0.063189  0.686273  0.553208
# 21  0.666445  0.725755  0.824062
# 22  0.810946  0.124496  0.825728
# 23  0.062855  0.175835  0.075378
# 24  0.782922  0.972773  0.961172
# 25  0.292650  0.201925  0.406342
# 26  0.166641  0.604784  0.632993
# ...

# %%
sns.scatterplot(
    data=df, x="X", y="Y", hue="Z", size="Z", palette="viridis", sizes=(50, 100)
)
plt.title("relationship between 3")
# Out:
# Text(0.5, 1.0, 'relationship between 3')

# %%
months = ["Jan", "Feb", "Mar", "Apr"]
store_1 = [2000, 2500, 2200, 2700]
store_2 = [1800, 2300, 2100, 2600]
store_3 = [2200, 2400, 2000, 2800]

x = np.arange(len(months))
width = 0.25

plt.bar(x - width, store_1, width, label="Store 1")
plt.bar(x, store_2, width, label="Store 2")
plt.bar(x + width, store_3, width, label="Store 3")

plt.xlabel("Month")
plt.ylabel("Revenue ($)")
plt.title("Average Monthly Revenue per Store")
plt.xticks(x, months)
plt.legend();

# %%
data1 = np.random.normal(50, 10, 1000)
data2 = np.random.normal(60, 15, 1000)

plt.hist(data1, bins=20, alpha=0.6, label="Dataset 1", color="blue")
plt.hist(data2, bins=20, alpha=0.8, label="Dataset 2", color="red")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Comparison")
plt.legend()

# %%
segments = [40, 25, 20, 15]
labels = ["Segment A", "Segment B", "Segment C", "Segment D"]
explode = (0.2, 0, 0, 0)  # Highlight first segment

plt.pie(segments, labels=labels, explode=explode, autopct="%1.1f%%", shadow=True)
plt.title("Customer Segment Percentages");

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
temperatures = np.arange(1, 8)  # 7 values

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
print(fig)
# Line plot
axes[0, 0].plot(days, temperatures, marker="o", color="orange")
axes[0, 0].set_title("Line Plot")

# Bar chart
axes[0, 1].bar(["A", "B", "C"], [10, 20, 15], color="green")
axes[0, 1].set_title("Bar Chart")

# Histogram
axes[1, 0].hist(np.random.randn(100), bins=10, color="purple")
axes[1, 0].set_title("Histogram")

# Scatter plot
axes[1, 1].scatter(np.random.rand(20), np.random.rand(20), color="red")
axes[1, 1].set_title("Scatter Plot")

plt.tight_layout()
# Out:
# Figure(1000x800)

# %%
cust = [22, 24, 21, 23, 25, 26, 24]

plt.plot(days, cust, marker="o", color="blue", linestyle="-")
plt.title("Weekly Temperature with Annotations")
plt.xlabel("Day")
plt.ylabel("Temperature (°C)")


max_temp = max(cust)
max_day = days[cust.index(max_temp)]
plt.annotate(
    f"Max: {max_temp}°C",
    xy=(max_day, max_temp),
    xytext=(max_day, max_temp + 1),
    arrowprops=dict(facecolor="red", shrink=0.05),
)

plt.grid(True)

# %%
matrix = np.random.rand(10, 10)
# print(matrix)
sns.heatmap(matrix, annot=True, cmap="coolwarm")
plt.title("10x10 Heatmap");

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
cust = [22, 24, 21, 23, 25, 26, 24]
# Line chart
axes[0].plot(days, cust, color="blue")
axes[0].set_title("Temperature Trend")
axes[0].set_xlabel("Day")
axes[0].set_ylabel("°C")

# Bar chart
axes[1].bar(["Store A", "Store B", "Store C"], [2000, 2500, 2200], color="green")
axes[1].set_title("Monthly Revenue")

# Pie chart
axes[2].pie(
    [40, 30, 30],
    labels=["Segment 1", "Segment 2", "Segment 3"],
    autopct="%1.1f%%",
    shadow=True,
    # explode=[0.1,0.1,0.1]
)
axes[2].set_title("Customer Segments")

plt.tight_layout()
